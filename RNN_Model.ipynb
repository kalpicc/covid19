# %%
import pandas as pd

# %%
df = pd.read_csv("covid19postvaxstatewidestats.csv")

# %%
df['area_type'].unique()
# Out:
# array(['State'], dtype=object)

# %%
df
# Out:
#            date        area area_type  unvaccinated_cases  vaccinated_cases  \
# 0    2021-02-01  California     State               14595                24
# 1    2021-02-02  California     State               12076                21
# 2    2021-02-03  California     State               11009                25
# 3    2021-02-04  California     State                9661                17
# 4    2021-02-05  California     State                8984                17
# ..          ...         ...       ...                 ...               ...
# 784  2023-03-27  California     State                 607              1016
# 785  2023-03-28  California     State                 502               980
# 786  2023-03-29  California     State                 539               924
# 787  2023-03-30  California     State                 481               961
# 788  2023-03-31  California     State                 408               902
#
#      unvaccinated_hosp  vaccinated_hosp  unvaccinated_deaths  \
# 0                  781                1                   12
# 1                  599                0                   15
# 2                  557                0                   18
# 3                  487                0                   19
# 4                  507                1                   27
# ..                 ...              ...                  ...
# 784                 33               83                    4
# 785                 28               74                    3
# 786                 37               81                    3
# 787                 38               65                    5
# 788                 30               78                    2
#
#      vaccinated_deaths  population_unvaccinated  population_vaccinated  \
# 0                    0                 36190068                 339372
# 1                    0                 36073331                 373679
# 2                    0                 35938325                 410320
# 3                    0                 35774605                 431692
# 4                    0                 35611210                 447446
# ..                 ...                      ...                    ...
# 784                  7                  5591769               28898483
# 785                  9                  5590686               28898869
# 786                  7                  5589458               28899278
# 787                  9                  5588295               28899658
# 788                  6                  5587014               28900059
#
#      unvaccinated_cases_per_100k  vaccinated_cases_per_100k  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ..                           ...                        ...
# 784                     8.425650                   3.002135
# 785                     8.210084                   2.952661
# 786                     8.268116                   2.931858
# 787                     8.157356                   2.942200
# 788                     8.008367                   2.942653
#
#      unvaccinated_hosp_per_100k  vaccinated_hosp_per_100k  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ..                          ...                       ...
# 784                    0.613146                  0.266944
# 785                    0.564715                  0.251122
# 786                    0.552060                  0.250130
# 787                    0.570069                  0.241723
# 788                    0.580428                  0.243697
#
#      unvaccinated_deaths_per_100k  vaccinated_deaths_per_100k
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ..                            ...                         ...
# 784                      0.051096                    0.027189
# 785                      0.048550                    0.029166
# 786                      0.048561                    0.029660
# 787                      0.061353                    0.029659
# 788                      0.056253                    0.031142
#
# [789 rows x 17 columns]

# %%
filtered_df = df[df['vaccinated_deaths_per_100k'].notnull()]

# %%
filtered_df
# Out:
#            date        area area_type  unvaccinated_cases  vaccinated_cases  \
# 6    2021-02-07  California     State                4911                 8
# 7    2021-02-08  California     State                8984                25
# 8    2021-02-09  California     State                7387                15
# 9    2021-02-10  California     State                7079                29
# 10   2021-02-11  California     State                6242                30
# ..          ...         ...       ...                 ...               ...
# 784  2023-03-27  California     State                 607              1016
# 785  2023-03-28  California     State                 502               980
# 786  2023-03-29  California     State                 539               924
# 787  2023-03-30  California     State                 481               961
# 788  2023-03-31  California     State                 408               902
#
#      unvaccinated_hosp  vaccinated_hosp  unvaccinated_deaths  \
# 6                  375                0                   45
# 7                  465                1                   37
# 8                  429                0                   38
# 9                  395                0                   47
# 10                 334                1                   48
# ..                 ...              ...                  ...
# 784                 33               83                    4
# 785                 28               74                    3
# 786                 37               81                    3
# 787                 38               65                    5
# 788                 30               78                    2
#
#      vaccinated_deaths  population_unvaccinated  population_vaccinated  \
# 6                    0                 35449430                 465455
# 7                    0                 35333157                 503581
# 8                    0                 35194037                 544831
# 9                    0                 35042985                 587459
# 10                   0                 34880775                 624724
# ..                 ...                      ...                    ...
# 784                  7                  5591769               28898483
# 785                  9                  5590686               28898869
# 786                  7                  5589458               28899278
# 787                  9                  5588295               28899658
# 788                  6                  5587014               28900059
#
#      unvaccinated_cases_per_100k  vaccinated_cases_per_100k  \
# 6                      27.251295                   3.805800
# 7                      25.072362                   3.546032
# 8                      23.268146                   3.120234
# 9                      21.766329                   2.991090
# 10                     20.467271                   3.109945
# ..                           ...                        ...
# 784                     8.425650                   3.002135
# 785                     8.210084                   2.952661
# 786                     8.268116                   2.931858
# 787                     8.157356                   2.942200
# 788                     8.008367                   2.942653
#
#      unvaccinated_hosp_per_100k  vaccinated_hosp_per_100k  \
# 6                      1.483401                  0.092076
# 7                      1.360519                  0.085105
# 8                      1.296892                  0.078661
# 9                      1.236441                  0.072953
# 10                     1.179528                  0.091469
# ..                          ...                       ...
# 784                    0.613146                  0.266944
# 785                    0.564715                  0.251122
# 786                    0.552060                  0.250130
# 787                    0.570069                  0.241723
# 788                    0.580428                  0.243697
#
#      unvaccinated_deaths_per_100k  vaccinated_deaths_per_100k
# 6                        0.067702                    0.000000
# 7                        0.078033                    0.000000
# 8                        0.087677                    0.000000
# 9                        0.099877                    0.000000
# 10                       0.112219                    0.000000
# ..                            ...                         ...
# 784                      0.051096                    0.027189
# 785                      0.048550                    0.029166
# 786                      0.048561                    0.029660
# 787                      0.061353                    0.029659
# 788                      0.056253                    0.031142
#
# [783 rows x 17 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10,5))
plt.plot()

# %%
df['date'] = pd.to_datetime(df['date'], format = "%Y-%m-%d")

df['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
plt.plot(df['date'], df['unvaccinated_cases'])
plt.plot(df['date'], df['vaccinated_cases'])
plt.xticks(rotation = 45)
plt.show()

# %%
plt.plot(df['date'],df['unvaccinated_cases_per_100k'], color = 'r')
plt.plot(df['date'],df['vaccinated_cases_per_100k'], color = 'g')
plt.xticks(rotation = 45)
plt.show()
